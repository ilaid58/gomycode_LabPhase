# %%
import pandas as pd
import numpy as np

# %%
dataset = [
    ['Skirt', 'Sneakers', 'Scarf', 'Pants', 'Hat'],
    ['Sunglasses', 'Skirt', 'Sneakers', 'Pants', 'Hat'],
    ['Dress', 'Sandals', 'Scarf', 'Pants', 'Heels'],
    ['Dress', 'Necklace', 'Earrings', 'Scarf', 'Hat', 'Heels', 'Hat'],
    ['Earrings', 'Skirt', 'Skirt', 'Scarf', 'Shirt', 'Pants']
    ]

# %% [markdown]
# #**Data Preparation**

# %%
from mlxtend.preprocessing import TransactionEncoder

# %%
te = TransactionEncoder()
te_array = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_array, columns=te.columns_)

# %%
df
# Out:
#    Dress  Earrings    Hat  Heels  Necklace  Pants  Sandals  Scarf  Shirt  \
# 0  False     False   True  False     False   True    False   True  False
# 1  False     False   True  False     False   True    False  False  False
# 2   True     False  False   True     False   True     True   True  False
# 3   True      True   True   True      True  False    False   True  False
# 4  False      True  False  False     False   True    False   True   True
#
#    Skirt  Sneakers  Sunglasses
# 0   True      True       False
# 1   True      True        True
# 2  False     False       False
# 3  False     False       False
# 4   True     False       False

# %% [markdown]
# #**Some visualization**

# %%
import plotly.express as px

# %%
for feat in df.columns:
  print(feat)
  fig = px.bar(df, x=feat)
  fig.update_traces(marker=dict(color='red', opacity=0.5, line=dict(color='red', width=0.5)))
  fig.show()
# Out:
# Dress
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ac1e6ecd-bfd5-4291-854f-dcb8e18f091a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac1e6ecd-bfd5-4291-854f-dcb8e18f091a")) {                    Plotly.newPlot(                        "ac1e6ecd-bfd5-4291-854f-dcb8e18f091a",                        [{"alignmentgroup":"True","hovertemplate":"Dress=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"red","pattern":{"shape":""},"line":{"color":"red","width":0.5},"opacity":0.5},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[false,false,true,true,false],"xaxis":"x","y":[1,1,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colo ...
# Earrings
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="56de43f8-fc06-46bd-964f-285aaa9d629e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56de43f8-fc06-46bd-964f-285aaa9d629e")) {                    Plotly.newPlot(                        "56de43f8-fc06-46bd-964f-285aaa9d629e",                        [{"alignmentgroup":"True","hovertemplate":"Earrings=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"red","pattern":{"shape":""},"line":{"color":"red","width":0.5},"opacity":0.5},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[false,false,false,true,true],"xaxis":"x","y":[1,1,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"c ...
# Hat
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f0165201-572e-4c78-8c7b-4232d08d1620" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0165201-572e-4c78-8c7b-4232d08d1620")) {                    Plotly.newPlot(                        "f0165201-572e-4c78-8c7b-4232d08d1620",                        [{"alignmentgroup":"True","hovertemplate":"Hat=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"red","pattern":{"shape":""},"line":{"color":"red","width":0.5},"opacity":0.5},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[true,true,false,true,false],"xaxis":"x","y":[1,1,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorba ...
# Heels
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="36251343-b607-4ae1-9f9a-3bec549de30c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36251343-b607-4ae1-9f9a-3bec549de30c")) {                    Plotly.newPlot(                        "36251343-b607-4ae1-9f9a-3bec549de30c",                        [{"alignmentgroup":"True","hovertemplate":"Heels=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"red","pattern":{"shape":""},"line":{"color":"red","width":0.5},"opacity":0.5},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[false,false,true,true,false],"xaxis":"x","y":[1,1,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colo ...
# Necklace
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cc6b4bb8-11fd-4655-a731-e0e4c21f534a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc6b4bb8-11fd-4655-a731-e0e4c21f534a")) {                    Plotly.newPlot(                        "cc6b4bb8-11fd-4655-a731-e0e4c21f534a",                        [{"alignmentgroup":"True","hovertemplate":"Necklace=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"red","pattern":{"shape":""},"line":{"color":"red","width":0.5},"opacity":0.5},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[false,false,false,true,false],"xaxis":"x","y":[1,1,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{" ...
# Pants
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c9786e37-0a41-4033-9e60-0fb0527d54c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9786e37-0a41-4033-9e60-0fb0527d54c6")) {                    Plotly.newPlot(                        "c9786e37-0a41-4033-9e60-0fb0527d54c6",                        [{"alignmentgroup":"True","hovertemplate":"Pants=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"red","pattern":{"shape":""},"line":{"color":"red","width":0.5},"opacity":0.5},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[true,true,true,false,true],"xaxis":"x","y":[1,1,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorb ...
# Sandals
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="bfe33e14-0a34-420f-abd7-607cdab6826d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bfe33e14-0a34-420f-abd7-607cdab6826d")) {                    Plotly.newPlot(                        "bfe33e14-0a34-420f-abd7-607cdab6826d",                        [{"alignmentgroup":"True","hovertemplate":"Sandals=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"red","pattern":{"shape":""},"line":{"color":"red","width":0.5},"opacity":0.5},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[false,false,true,false,false],"xaxis":"x","y":[1,1,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"c ...
# Scarf
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="9ca2f3ba-58e5-4daf-9135-99c6586d90be" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9ca2f3ba-58e5-4daf-9135-99c6586d90be")) {                    Plotly.newPlot(                        "9ca2f3ba-58e5-4daf-9135-99c6586d90be",                        [{"alignmentgroup":"True","hovertemplate":"Scarf=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"red","pattern":{"shape":""},"line":{"color":"red","width":0.5},"opacity":0.5},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[true,false,true,true,true],"xaxis":"x","y":[1,1,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorb ...
# Shirt
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="80d08d0d-6cb2-4550-a968-8f67670ecad4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80d08d0d-6cb2-4550-a968-8f67670ecad4")) {                    Plotly.newPlot(                        "80d08d0d-6cb2-4550-a968-8f67670ecad4",                        [{"alignmentgroup":"True","hovertemplate":"Shirt=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"red","pattern":{"shape":""},"line":{"color":"red","width":0.5},"opacity":0.5},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[false,false,false,false,true],"xaxis":"x","y":[1,1,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"col ...
# Skirt
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8c1777f0-9faa-4b8a-8d21-b5d914b1bf33" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8c1777f0-9faa-4b8a-8d21-b5d914b1bf33")) {                    Plotly.newPlot(                        "8c1777f0-9faa-4b8a-8d21-b5d914b1bf33",                        [{"alignmentgroup":"True","hovertemplate":"Skirt=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"red","pattern":{"shape":""},"line":{"color":"red","width":0.5},"opacity":0.5},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[true,true,false,false,true],"xaxis":"x","y":[1,1,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"color ...
# Sneakers
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="fb453ace-fdce-457a-b5e8-de19bf060718" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb453ace-fdce-457a-b5e8-de19bf060718")) {                    Plotly.newPlot(                        "fb453ace-fdce-457a-b5e8-de19bf060718",                        [{"alignmentgroup":"True","hovertemplate":"Sneakers=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"red","pattern":{"shape":""},"line":{"color":"red","width":0.5},"opacity":0.5},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[true,true,false,false,false],"xaxis":"x","y":[1,1,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"c ...
# Sunglasses
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d5e3d163-b3ec-474e-ace4-f5bedca8a427" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5e3d163-b3ec-474e-ace4-f5bedca8a427")) {                    Plotly.newPlot(                        "d5e3d163-b3ec-474e-ace4-f5bedca8a427",                        [{"alignmentgroup":"True","hovertemplate":"Sunglasses=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"red","pattern":{"shape":""},"line":{"color":"red","width":0.5},"opacity":0.5},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[false,true,false,false,false],"xaxis":"x","y":[1,1,1,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker": ...

# %% [markdown]
# #**Apriori Algorithm**

# %%
from mlxtend.frequent_patterns import *

# %%
frequent_items = apriori(df, min_support=0.6, use_colnames=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.

# %%
frequent_items
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#    support        itemsets
# 0      0.6           (Hat)
# 1      0.8         (Pants)
# 2      0.8         (Scarf)
# 3      0.6         (Skirt)
# 4      0.6  (Scarf, Pants)
# 5      0.6  (Pants, Skirt)

# %%
df_lift = association_rules(frequent_items, metric='lift')
df_lift
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   antecedents consequents  antecedent support  consequent support  support  \
# 0     (Scarf)     (Pants)                 0.8                 0.8      0.6
# 1     (Pants)     (Scarf)                 0.8                 0.8      0.6
# 2     (Pants)     (Skirt)                 0.8                 0.6      0.6
# 3     (Skirt)     (Pants)                 0.6                 0.8      0.6
#
#    confidence    lift  leverage  conviction  zhangs_metric
# 0        0.75  0.9375     -0.04         0.8          -0.25
# 1        0.75  0.9375     -0.04         0.8          -0.25
# 2        0.75  1.2500      0.12         1.6           1.00
# 3        1.00  1.2500      0.12         inf           0.50

# %% [markdown]
# **The items that should be put together are :**
#
# **✈ *Pants*** WITH ***Skirt***
#
# **✈ *Skirt*** WITH ***Pants***

# %% [markdown]
# #**Now let use a big dataset**

# %% [markdown]
# ##**Import the dataset**

# %%
from pydrive.auth import GoogleAuth

from pydrive.drive import GoogleDrive

from google.colab import auth

from oauth2client.client import GoogleCredentials
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.

# %%
auth.authenticate_user()

gauth = GoogleAuth()

gauth.credentials = GoogleCredentials.get_application_default()

drive = GoogleDrive(gauth)

file_download = drive.CreateFile({'id':'109dPPJzZbjzMUp3JQBx5rQ538fzMNYzU'})

file_download.GetContentFile('Market_Basket_Optimisation.csv')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.

# %%
big_df = pd.read_csv('Market_Basket_Optimisation.csv')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.

# %%
big_df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#               shrimp            almonds      avocado    vegetables mix  \
# 0            burgers          meatballs         eggs               NaN
# 1            chutney                NaN          NaN               NaN
# 2             turkey            avocado          NaN               NaN
# 3      mineral water               milk   energy bar  whole wheat rice
# 4     low fat yogurt                NaN          NaN               NaN
# ...              ...                ...          ...               ...
# 7495          butter         light mayo  fresh bread               NaN
# 7496         burgers  frozen vegetables         eggs      french fries
# 7497         chicken                NaN          NaN               NaN
# 7498        escalope          green tea          NaN               NaN
# 7499            eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#      green grapes whole weat flour yams cottage cheese energy drink  \
# 0             NaN              NaN  NaN            NaN          NaN
# 1             NaN              NaN  NaN            NaN          NaN
# 2             NaN              NaN  NaN            NaN          NaN
# 3       green tea              NaN  NaN            NaN          NaN
# 4             NaN              NaN  NaN            NaN          NaN
# ...           ...              ...  ...            ...          ...
# 7495          NaN              NaN  NaN            NaN          NaN
# 7496    magazines        green tea  NaN            NaN          NaN
# 7497          NaN              NaN  NaN            NaN          NaN
# 7498          NaN              NaN  NaN            NaN          NaN
# 7499          NaN              NaN  NaN            NaN          NaN
#
#      tomato juice low fat yogurt green tea honey salad mineral water salmon  \
# 0             NaN            NaN       NaN   NaN   NaN           NaN    NaN
# 1             NaN            NaN       NaN   NaN   NaN           NaN    NaN
# 2             NaN            NaN       NaN   NaN   NaN           NaN    NaN
# 3             NaN            NaN       NaN   NaN   NaN           NaN    NaN
# 4             NaN            NaN       NaN   NaN   NaN           NaN    NaN
# ...           ...            ...       ...   ...   ...           ...    ...
# 7495          NaN            NaN       NaN   NaN   NaN           NaN    NaN
# 7496          NaN            NaN       NaN   NaN   NaN           NaN    NaN
# 7497          NaN            NaN       NaN   NaN   NaN           NaN    NaN
# 7498          NaN            NaN       NaN   NaN   NaN           NaN    NaN
# 7499          NaN            NaN       NaN   NaN   NaN           NaN    NaN
#
#      antioxydant juice frozen smoothie spinach  olive oil
# 0                  NaN             NaN     NaN        NaN
# 1                  NaN             NaN     NaN        NaN
# 2                  NaN             NaN     NaN        NaN
# 3                  NaN             NaN     NaN        NaN
# 4                  NaN             NaN     NaN        NaN
# ...                ...             ...     ...        ...
# 7495               NaN             NaN     NaN        NaN
# 7496               NaN             NaN     NaN        NaN
# 7497               NaN             NaN     NaN        NaN
# 7498               NaN             NaN     NaN        NaN
# 7499               NaN             NaN     NaN        NaN
#
# [7500 rows x 20 columns]

# %%
big_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   shrimp             7500 non-null   object
#  1   almonds            5746 non-null   object
#  2   avocado            4388 non-null   object
#  3   vegetables mix     3344 non-null   object
#  4   green grapes       2528 non-null   object
#  5   whole weat flour   1863 non-null   object
#  6   yams               1368 non-null   object
#  7   cottage cheese     980 non-null    object
#  8   energy drink       653 non-null    object
#  9   tomato juice       394 non-null    object
#  10  low fat yogurt     255 non-null    object
#  11  green tea          153 non-null    object
#  12  honey              86 non-null     object
#  13  salad              46 non-null     object
#  14  mineral water      24 non-null     object
#  15  salmon             7 non-null      object
#  16  antioxydant juice  3 non-null      object
#  17  frozen smoothie    3 non-null      object
#  18  spinach            2 non-null      object
#  19  olive oil          0 non-null      float64
# dtypes: float64(1), object(19)
# memory usage: 1.1+ MB
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.

# %% [markdown]
# ##**Data Preprocessing**

# %%
datasets = pd.DataFrame({})
for col in big_df.columns:
  n = big_df[col].dropna().values
  datasets[col] = big_df[col].replace(n, col)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.

# %%
datasets
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#       shrimp  almonds  avocado  vegetables mix  green grapes  \
# 0     shrimp  almonds  avocado             NaN           NaN
# 1     shrimp      NaN      NaN             NaN           NaN
# 2     shrimp  almonds      NaN             NaN           NaN
# 3     shrimp  almonds  avocado  vegetables mix  green grapes
# 4     shrimp      NaN      NaN             NaN           NaN
# ...      ...      ...      ...             ...           ...
# 7495  shrimp  almonds  avocado             NaN           NaN
# 7496  shrimp  almonds  avocado  vegetables mix  green grapes
# 7497  shrimp      NaN      NaN             NaN           NaN
# 7498  shrimp  almonds      NaN             NaN           NaN
# 7499  shrimp  almonds  avocado  vegetables mix           NaN
#
#       whole weat flour yams cottage cheese energy drink tomato juice  \
# 0                  NaN  NaN            NaN          NaN          NaN
# 1                  NaN  NaN            NaN          NaN          NaN
# 2                  NaN  NaN            NaN          NaN          NaN
# 3                  NaN  NaN            NaN          NaN          NaN
# 4                  NaN  NaN            NaN          NaN          NaN
# ...                ...  ...            ...          ...          ...
# 7495               NaN  NaN            NaN          NaN          NaN
# 7496  whole weat flour  NaN            NaN          NaN          NaN
# 7497               NaN  NaN            NaN          NaN          NaN
# 7498               NaN  NaN            NaN          NaN          NaN
# 7499               NaN  NaN            NaN          NaN          NaN
#
#      low fat yogurt green tea honey salad mineral water salmon  \
# 0               NaN       NaN   NaN   NaN           NaN    NaN
# 1               NaN       NaN   NaN   NaN           NaN    NaN
# 2               NaN       NaN   NaN   NaN           NaN    NaN
# 3               NaN       NaN   NaN   NaN           NaN    NaN
# 4               NaN       NaN   NaN   NaN           NaN    NaN
# ...             ...       ...   ...   ...           ...    ...
# 7495            NaN       NaN   NaN   NaN           NaN    NaN
# 7496            NaN       NaN   NaN   NaN           NaN    NaN
# 7497            NaN       NaN   NaN   NaN           NaN    NaN
# 7498            NaN       NaN   NaN   NaN           NaN    NaN
# 7499            NaN       NaN   NaN   NaN           NaN    NaN
#
#      antioxydant juice frozen smoothie spinach  olive oil
# 0                  NaN             NaN     NaN        NaN
# 1                  NaN             NaN     NaN        NaN
# 2                  NaN             NaN     NaN        NaN
# 3                  NaN             NaN     NaN        NaN
# 4                  NaN             NaN     NaN        NaN
# ...                ...             ...     ...        ...
# 7495               NaN             NaN     NaN        NaN
# 7496               NaN             NaN     NaN        NaN
# 7497               NaN             NaN     NaN        NaN
# 7498               NaN             NaN     NaN        NaN
# 7499               NaN             NaN     NaN        NaN
#
# [7500 rows x 20 columns]

# %%
data = []
m, _ = datasets.shape
for row in range(m):
  n = datasets.iloc[row].dropna().values.tolist()
  data.append(n)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.

# %%
data
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
# [['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice'],
#  ['shrimp'],
#  ['shrimp'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp', 'almonds'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp', 'almonds', 'avocado'],
#  ['shrimp'],
#  ['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea'],
#  ['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink'],
#  ...]

# %% [markdown]
# ##**Define the dataframe**

# %%
te = TransactionEncoder()
array = te.fit(data).transform(data)
df2 = pd.DataFrame(array, columns=te.columns_)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.

# %%
df2['olive oil'] = False # Because the 'olive oil' are not in any transaction
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.

# %%
df2
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#       almonds  antioxydant juice  avocado  cottage cheese  energy drink  \
# 0        True              False     True           False         False
# 1       False              False    False           False         False
# 2        True              False    False           False         False
# 3        True              False     True           False         False
# 4       False              False    False           False         False
# ...       ...                ...      ...             ...           ...
# 7495     True              False     True           False         False
# 7496     True              False     True           False         False
# 7497    False              False    False           False         False
# 7498     True              False    False           False         False
# 7499     True              False     True           False         False
#
#       frozen smoothie  green grapes  green tea  honey  low fat yogurt  \
# 0               False         False      False  False           False
# 1               False         False      False  False           False
# 2               False         False      False  False           False
# 3               False          True      False  False           False
# 4               False         False      False  False           False
# ...               ...           ...        ...    ...             ...
# 7495            False         False      False  False           False
# 7496            False          True      False  False           False
# 7497            False         False      False  False           False
# 7498            False         False      False  False           False
# 7499            False         False      False  False           False
#
#       mineral water  salad  salmon  shrimp  spinach  tomato juice  \
# 0             False  False   False    True    False         False
# 1             False  False   False    True    False         False
# 2             False  False   False    True    False         False
# 3             False  False   False    True    False         False
# 4             False  False   False    True    False         False
# ...             ...    ...     ...     ...      ...           ...
# 7495          False  False   False    True    False         False
# 7496          False  False   False    True    False         False
# 7497          False  False   False    True    False         False
# 7498          False  False   False    True    False         False
# 7499          False  False   False    True    False         False
#
#       vegetables mix  whole weat flour   yams  olive oil
# 0              False             False  False      False
# 1              False             False  False      False
# 2              False             False  False      False
# 3               True             False  False      False
# 4              False             False  False      False
# ...              ...               ...    ...        ...
# 7495           False             False  False      False
# 7496            True              True  False      False
# 7497           False             False  False      False
# 7498           False             False  False      False
# 7499            True             False  False      False
#
# [7500 rows x 20 columns]

# %% [markdown]
# # **Apriori Algorithm**

# %%
frequent_items = apriori(df2, min_support=0.5, use_colnames=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.

# %%
print(frequent_items)
df_lift = association_rules(frequent_items, metric='lift')
# Out:
#     support                    itemsets
# 0  0.766133                   (almonds)
# 1  0.585067                   (avocado)
# 2  1.000000                    (shrimp)
# 3  0.585067          (avocado, almonds)
# 4  0.766133           (shrimp, almonds)
# 5  0.585067           (shrimp, avocado)
# 6  0.585067  (shrimp, avocado, almonds)
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.

# %%
df_lift
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#            antecedents         consequents  antecedent support  \
# 0            (avocado)           (almonds)            0.585067
# 1            (almonds)           (avocado)            0.766133
# 2             (shrimp)           (almonds)            1.000000
# 3            (almonds)            (shrimp)            0.766133
# 4             (shrimp)           (avocado)            1.000000
# 5            (avocado)            (shrimp)            0.585067
# 6    (shrimp, avocado)           (almonds)            0.585067
# 7    (shrimp, almonds)           (avocado)            0.766133
# 8   (avocado, almonds)            (shrimp)            0.585067
# 9             (shrimp)  (avocado, almonds)            1.000000
# 10           (avocado)   (shrimp, almonds)            0.585067
# 11           (almonds)   (shrimp, avocado)            0.766133
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0             0.766133  0.585067    1.000000  1.305256  0.136828         inf
# 1             0.585067  0.585067    0.763662  1.305256  0.136828    1.755675
# 2             0.766133  0.766133    0.766133  1.000000  0.000000    1.000000
# 3             1.000000  0.766133    1.000000  1.000000  0.000000         inf
# 4             0.585067  0.585067    0.585067  1.000000  0.000000    1.000000
# 5             1.000000  0.585067    1.000000  1.000000  0.000000         inf
# 6             0.766133  0.585067    1.000000  1.305256  0.136828         inf
# 7             0.585067  0.585067    0.763662  1.305256  0.136828    1.755675
# 8             1.000000  0.585067    1.000000  1.000000  0.000000         inf
# 9             0.585067  0.585067    0.585067  1.000000  0.000000    1.000000
# 10            0.766133  0.585067    1.000000  1.305256  0.136828         inf
# 11            0.585067  0.585067    0.763662  1.305256  0.136828    1.755675
#
#     zhangs_metric
# 0        0.563625
# 1        1.000000
# 2        0.000000
# 3        0.000000
# 4        0.000000
# 5        0.000000
# 6        0.563625
# 7        1.000000
# 8        0.000000
# 9        0.000000
# 10       0.563625
# 11       1.000000

# %%
df_lift[df_lift['lift'] > df_lift['lift'].mean()]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#           antecedents        consequents  antecedent support  \
# 0           (avocado)          (almonds)            0.585067
# 1           (almonds)          (avocado)            0.766133
# 6   (shrimp, avocado)          (almonds)            0.585067
# 7   (shrimp, almonds)          (avocado)            0.766133
# 10          (avocado)  (shrimp, almonds)            0.585067
# 11          (almonds)  (shrimp, avocado)            0.766133
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0             0.766133  0.585067    1.000000  1.305256  0.136828         inf
# 1             0.585067  0.585067    0.763662  1.305256  0.136828    1.755675
# 6             0.766133  0.585067    1.000000  1.305256  0.136828         inf
# 7             0.585067  0.585067    0.763662  1.305256  0.136828    1.755675
# 10            0.766133  0.585067    1.000000  1.305256  0.136828         inf
# 11            0.585067  0.585067    0.763662  1.305256  0.136828    1.755675
#
#     zhangs_metric
# 0        0.563625
# 1        1.000000
# 6        0.563625
# 7        1.000000
# 10       0.563625
# 11       1.000000

# %% [markdown]
# **The items that should be put together :**
#
# **✈ *avocado*** WITH ***almonds***
#
# **✈ (*shrimp* + *avocado*)** WITH ***almonds***
#
# **✈ (*shrimp* + *almonds*)** WITH ***avocado***
#
# **✈ *avocado*** WITH **(*shrimp* + *almonds*)**
#
# **✈ *almonds*** WITH **(*shrimp* + *avocado*)**
