# %% [markdown]
# #**2. Import the library**

# %%
# !pip install fastapi
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.0/67.0 kB 5.4 MB/s eta 0:00:00
# ...

# %%
import requests
import pandas as pd

# %%
api_key = 'boFqOpDQ292mVWRinYtpvZTpDZxamKv0io9ptfm6'

# %% [markdown]
# #**5. Ask API endpoint and display picture**

# %%
import cv2

# %%
url = 'https://apod.nasa.gov/apod/image/2309/STSCI-HST-abell370_1797x2000.jpg'

# %%
r = requests.get(url)

# %%
r.content
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
f1 = open('myimage2.png', 'w+b')
f1.write(r.content)
# Out:
# 1376388

# %%
from skimage import io
import os

# %%
os.listdir()
# Out:
# ['.config', 'image.png', 'myimage2.png', 'sample_data']

# %%
img = io.imread('image.png')
io.imshow(img)

# %% [markdown]
# #**6. Store the result in pandas DataFrame**

# %%
r.headers
# Out:
# {'Server': 'WebServer/1.0', 'X-Frame-Options': 'sameorigin', 'Last-Modified': 'Mon, 28 Aug 2023 20:23:11 GMT', 'ETag': '"5710c48-150084-60401769726ff"', 'Accept-Ranges': 'bytes', 'Keep-Alive': 'timeout=5, max=100', 'Content-Type': 'image/jpeg', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains', 'Content-Security-Policy': 'upgrade-insecure-requests', 'Connection': 'Keep-Alive', 'Date': 'Wed, 13 Sep 2023 20:43:31 GMT', 'Age': '581', 'Content-Length': '1376388'}

# %%
json
